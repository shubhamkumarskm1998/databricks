# %% [markdown]
# ##Access to Cloud Storage

# %%
# %fs ls "abfss://demo@deacourseextdlshubh.dfs.core.windows.net/"

# %% [markdown]
# ##Create External Location

# %%
# %sql
Create external Location if not exists dea_course_ext_dl_demo
URL 'abfss://demo@deacourseextdlshubh.dfs.core.windows.net/'
with (storage credential dea-course-ext-sc)
comment "DEA Course External Location"
